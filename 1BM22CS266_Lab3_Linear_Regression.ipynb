# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamitawa/ML/blob/main/1BM22CS266_Lab3_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear Regression using slope
import numpy as np
import matplotlib.pyplot as plt

# Example data
X = np.array([1, 2, 3, 4, 5])  # Feature (independent variable)
y = np.array([1.2, 1.8, 2.6, 3.2, 3.8])  # Target (dependent variable)

# Number of data points
n = len(X)

# Calculate the required sums
sum_x = np.sum(X)
sum_y = np.sum(y)
sum_xy = np.sum(X * y)
sum_x2 = np.sum(X ** 2)

# Calculate the slope (a1) and intercept (a0)
a1 = (n * sum_xy - sum_x * sum_y) / (n * sum_x2 - sum_x ** 2)
a0 = (sum_y - a1 * sum_x) / n

# Make predictions
y_pred = a1 * X + a0

# Plot the data points and the regression line
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.title('Linear Regression (Using Formula)')
plt.xlabel('X (Feature)')
plt.ylabel('y (Target)')
plt.legend()
plt.show()

# Print the results
print(f"Slope (a1): {a1}")
print(f"Intercept (a0): {a0}")
print(f"Predictions (y = a1 * x + a0):")
print(f"  x = {9}, y_pred = {yi_pred}")
# Out:
# Slope (a1): 0.66
# Intercept (a0): 0.5400000000000003
# Predictions (y = a1 * x + a0):
#   x = 9, y_pred = 3.8400000000000007

# %%
#Linear Regression using Matrix Form

import numpy as np
import matplotlib.pyplot as plt

# Example data
X = np.array([1, 2, 3, 4, 5])  # Feature (independent variable)
y = np.array([1.2, 1.8, 2.6, 3.2, 3.8])  # Target (dependent variable)

# Add bias term (column of 1s) to X
X_matrix = np.c_[np.ones(len(X)), X]  # Creates a matrix with [1, X] format

# Calculate theta (slope and intercept) using normal equation
theta = np.linalg.inv(X_matrix.T @ X_matrix) @ X_matrix.T @ y

# Extract intercept and slope
b, m = theta

# Make predictions
y_pred = m * X + b

# Print the results
print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")

# Plot data points and regression line
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.title('Linear Regression (Matrix Form)')
plt.xlabel('X (Feature)')
plt.ylabel('y (Target)')
plt.legend()
plt.show()
# Out:
# Slope (m): 0.6600000000000001
# Intercept (b): 0.5400000000000025
